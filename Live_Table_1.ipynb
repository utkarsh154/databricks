# %%
from pyspark.sql.functions import *

# Read the CSV file
raw_df = spark.read.options(header="true", inferSchema="true").csv("/Volumes/dbw_de_training/default/utkarshk/diabetes.csv")

# %%
bronze_df=raw_df.withColumn("ingest_time", current_timestamp())
bronze_df.write.format("delta").mode("overwrite").save("/Volumes/dbw_de_training/default/utkarshk/bronze/")
